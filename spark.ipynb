# %% [markdown]
# # Introduction to Big Data Modern Technologies course

# %% [markdown]
# ## FINAL PROJECT: lab work
# ### Part 1. Object storage and database pipeline (Spark)

# %% [markdown]
# ### 1. Libraries and credentials

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/conda/lib/python3.9/site-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in /opt/conda/lib/python3.9/site-packages (from pyspark) (0.10.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import io
import sys
import json
import boto3
import logging
import psycopg2
import requests
import datetime
import multiprocessing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import udf, struct, countDistinct

# %%
def access_data(file_path):
    with open(file_path) as file:
        access_data = json.load(file)
    return access_data

creds = access_data(file_path='Selezneva_access_bucket.json')
print(creds.keys())
# Out:
# dict_keys(['aws_access_key_id', 'aws_secret_access_key'])

# %% [markdown]
# ### 2. Browse files at S3

# %%
session = boto3.session.Session()
s3 = session.client(
    service_name='s3',
    aws_access_key_id=creds['aws_access_key_id'],
    aws_secret_access_key=creds['aws_secret_access_key'],
    endpoint_url='https://storage.yandexcloud.net'
)

# %%
DATA_BUCKET = 'shelkoviydivan'

# %%
all_files = [key['Key'] for key in s3.list_objects(Bucket=DATA_BUCKET)['Contents']]
print('files in storage:', all_files[:10]) # works only for num of files < 1000
# Out:
# files in storage: ['DataCoSupplyChainDataset.csv', 'DescriptionDataCoSupplyChain.csv', 'jhub_logs_large.csv', 'tokenized_access_logs.csv']

# %% [markdown]
# ### 3. Connection to database

# %% [markdown]
# ##### <font color='blue'>ClickHouse</font>

# %%
PATH_TO_JAR = '/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/jars/clickhouse-jdbc-0.4.0-shaded.jar'
CLICKHOUSE_JAR = f'file://{PATH_TO_JAR}'

# %%
def execute_query(query, access_ch, data=None):
    url = 'https://{host}:{port}/'.format(
        host=access_ch['host'],
        port=access_ch['port']
    )
    params = {
        'database': access_ch['dbname'],
        'query': query.strip()
    }
    auth = {
        'X-ClickHouse-User': access_ch['user'],
        'X-ClickHouse-Key': access_ch['password']
    }
    rs = requests.post(
        url, 
        params=params, 
        headers=auth, 
        data=data,
        verify=f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_ch["sslrootcert"]}'
    )
    return rs

# %%
access_ch = access_data('access_ch.json')
print(access_ch.keys())
# Out:
# dict_keys(['host', 'port', 'dbname', 'user', 'password', 'sslrootcert'])

# %%
access_ch.values()
# Out:
# dict_values(['rc1a-khd773h8uvvb9sug.mdb.yandexcloud.net', 8443, 'db1', 'user1', 'pasword1', 'YandexInternalRootCA.crt'])

# %%
query = '''
SELECT version()
'''
rs = execute_query(query, access_ch)
rs.text
# Out:
# '23.3.1.2823\n'

# %% [markdown]
# ##### <font color='green'>PostgreSQL</font>

# %%
access_postgres = access_data('access_postgres.json')
print(access_postgres.keys())
# Out:
# dict_keys(['host', 'port', 'dbname', 'user', 'password', 'sslrootcert'])

# %%
#access_postgres

# %%
def send_query(query, access_postgres, res=False):
    result = None
    with psycopg2.connect(
        host=access_postgres['host'],
        port=access_postgres['port'],
        dbname=access_postgres['dbname'],
        user=access_postgres['user'],
        password=access_postgres['password'],
        target_session_attrs='read-write',
        sslmode='verify-full',
        sslrootcert=f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_postgres["sslrootcert"]}'
        ) as conn:
            with conn.cursor() as cur:
                cur.execute(query)
                if res:
                    result = cur.fetchall()
    return result

# %%
query = '''
SELECT version()
'''
send_query(query, access_postgres, res=True)
# Out:
# [('PostgreSQL 14.7 (Ubuntu 14.7-201-yandex.52766.d65626c879) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0, 64-bit',)]

# %% [markdown]
# ### 4. Data preprocessing with Spark

# %%
# web UI for the Spark

def uiWebUrl(self):
    from urllib.parse import urlparse
    web_url = self._jsc.sc().uiWebUrl().get()
    port = urlparse(web_url).port
    return '{}proxy/{}/jobs/'.format(os.environ['JUPYTERHUB_SERVICE_PREFIX'], port)

SparkContext.uiWebUrl = property(uiWebUrl)

# Spark settings
conf = SparkConf()
conf.set('spark.master', 'local[*]')    # max 5 cores available
conf.set('spark.driver.memory', '12G')  # max 16 GB available
conf.set('spark.driver.extraClassPath', CLICKHOUSE_JAR) # CH connect
sc = SparkContext(conf=conf)
spark = SparkSession(sc)

# Spark's access for object storage settings
spark._jsc.hadoopConfiguration().set('fs.s3a.access.key', creds['aws_access_key_id'])
spark._jsc.hadoopConfiguration().set('fs.s3a.secret.key', creds['aws_secret_access_key'])
spark._jsc.hadoopConfiguration().set('fs.s3a.impl','org.apache.hadoop.fs.s3a.S3AFileSystem')
spark._jsc.hadoopConfiguration().set('fs.s3a.multipart.size', '104857600')
spark._jsc.hadoopConfiguration().set('fs.s3a.block.size', '33554432')
spark._jsc.hadoopConfiguration().set('fs.s3a.threads.max', '256')
spark._jsc.hadoopConfiguration().set('fs.s3a.endpoint', 'http://storage.yandexcloud.net')

spark
# Out:
# 23/04/13 11:35:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/user/st110205/proxy/4040/jobs/">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# #### 4.1. Read data with Spark

# %%
sdf = spark.read.csv(
    f's3a://{DATA_BUCKET}/jhub_logs_large.csv',
    sep=';', 
    header=True,
    multiLine=True, # if you have `\n` symbols
    escape="\""
)
sdf.printSchema()
# Out:
# 23/04/13 11:35:35 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# root
#  |-- date: string (nullable = true)
#  |-- kubernetes: string (nullable = true)
#  |-- log: string (nullable = true)
#  |-- stream: string (nullable = true)
#  |-- time: string (nullable = true)

# %%
sdf.show(5)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+
# |                date|          kubernetes|                 log|stream|                time|
# +--------------------+--------------------+--------------------+------+--------------------+
# |2022-12-09T04:50:...|Row(annotations=R...|[I 2022-12-09 04:...|stderr|2022-12-09T04:50:...|
# |2022-12-09T04:50:...|Row(annotations=R...|[W 2022-12-09 04:...|stderr|2022-12-09T04:50:...|
# |2022-12-09T04:50:...|Row(annotations=R...|[I 2022-12-09 04:...|stderr|2022-12-09T04:50:...|
# |2022-12-09T04:50:...|Row(annotations=R...|[W 2022-12-09 04:...|stderr|2022-12-09T04:50:...|
# |2022-12-09T04:50:...|Row(annotations=R...|[I 2022-12-09 04:...|stderr|2022-12-09T04:50:...|
# +--------------------+--------------------+--------------------+------+--------------------+
# only showing top 5 rows

# %% [markdown]
# #### 4.2. Kubernetes logs

# %%
def row_info(rin):
    """
    Extracts names of:
      - docker image
      - id of the Jupyter application
      - name of the host, where Jupyter runs
    
    """
    img = rin[rin.find('container_image='):].split('\'')[1]
    hub = rin[rin.find('pod_name='):].split('\'')[1]
    host = rin[rin.find('host='):].split('\'')[1]
    return img, hub, host

# %%
udf_row_info = udf(row_info, ArrayType(StringType()))

# %%
sdf = sdf.withColumn('kubernetes_msg', udf_row_info('kubernetes'))
sdf.limit(5).toPandas()
# Out:
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#                           date  \
# 0  2022-12-09T04:50:48.335844Z
# 1  2022-12-09T04:50:48.359937Z
# 2  2022-12-09T04:50:55.940651Z
# 3  2022-12-09T04:50:55.968410Z
# 4  2022-12-09T04:50:51.758320Z
#
#                                           kubernetes  \
# 0  Row(annotations=Row(checksum/config-map='ce892...
# 1  Row(annotations=Row(checksum/config-map='ce892...
# 2  Row(annotations=Row(checksum/config-map='ce892...
# 3  Row(annotations=Row(checksum/config-map='ce892...
# 4  Row(annotations=Row(checksum/config-map='ce892...
#
#                                                  log  stream  \
# 0  [I 2022-12-09 04:50:48.335 JupyterHub log:181]...  stderr
# 1  [W 2022-12-09 04:50:48.359 JupyterHub log:181]...  stderr
# 2  [I 2022-12-09 04:50:55.940 JupyterHub log:181]...  stderr
# 3  [W 2022-12-09 04:50:55.968 JupyterHub log:181]...  stderr
# 4  [I 2022-12-09 04:50:51.758 JupyterHub log:181]...  stderr
#
#                              time  \
# 0   2022-12-09T04:50:48.33584421Z
# 1  2022-12-09T04:50:48.359937031Z
# 2  2022-12-09T04:50:55.940651688Z
# 3  2022-12-09T04:50:55.968410334Z
# 4  2022-12-09T04:50:51.758320284Z
#
#                                       kubernetes_msg
# 0  [jupyterhub/k8s-hub:0.11.1, hub-5c66c6c96f-p5x...
# 1  [jupyterhub/k8s-hub:0.11.1, hub-5c66c6c96f-p5x...
# 2  [jupyterhub/k8s-hub:0.11.1, hub-5c66c6c96f-p5x...
# 3  [jupyterhub/k8s-hub:0.11.1, hub-5c66c6c96f-p5x...
# 4  [jupyterhub/k8s-hub:0.11.1, hub-5c66c6c96f-p5x...

# %%
sdf = sdf.select(
    'date',
    F.col('kubernetes_msg')[0].alias('img'),
    F.col('kubernetes_msg')[1].alias('hub'),
    F.col('kubernetes_msg')[2].alias('host'),
    'log',
    'stream',
    'time'
)
sdf.limit(5).toPandas()
# Out:
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#                           date                        img  \
# 0  2022-12-09T04:50:48.335844Z  jupyterhub/k8s-hub:0.11.1
# 1  2022-12-09T04:50:48.359937Z  jupyterhub/k8s-hub:0.11.1
# 2  2022-12-09T04:50:55.940651Z  jupyterhub/k8s-hub:0.11.1
# 3  2022-12-09T04:50:55.968410Z  jupyterhub/k8s-hub:0.11.1
# 4  2022-12-09T04:50:51.758320Z  jupyterhub/k8s-hub:0.11.1
#
#                     hub                       host  \
# 0  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 2  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 3  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 4  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
#
#                                                  log  stream  \
# 0  [I 2022-12-09 04:50:48.335 JupyterHub log:181]...  stderr
# 1  [W 2022-12-09 04:50:48.359 JupyterHub log:181]...  stderr
# 2  [I 2022-12-09 04:50:55.940 JupyterHub log:181]...  stderr
# 3  [W 2022-12-09 04:50:55.968 JupyterHub log:181]...  stderr
# 4  [I 2022-12-09 04:50:51.758 JupyterHub log:181]...  stderr
#
#                              time
# 0   2022-12-09T04:50:48.33584421Z
# 1  2022-12-09T04:50:48.359937031Z
# 2  2022-12-09T04:50:55.940651688Z
# 3  2022-12-09T04:50:55.968410334Z
# 4  2022-12-09T04:50:51.758320284Z

# %% [markdown]
# #### 4.3. JupyterHub logs

# %%
def sq_brackets(sin):
    """
    Split log string amd extracts:
      - timestamp of the event
      - name of application
      - type of logs
      - code of event
      - description
    
    """
    try:
        s = sin.split('[', 1)[1].split(']')[0]
        msg = sin[len(s) + 2 :].strip()
        s = s.split()
        head = s[0]
        ts = ' '.join(s[1:3])
        svc = s[3]
        typ = s[4].split(':')[0]
        code = s[4].split(':')[1]
    except:
        head, ts, svc, typ, code = '', '', '', '', ''
        msg = sin
    return head, ts, svc, typ, code, msg

# %%
udf_sq_brackets = udf(sq_brackets, ArrayType(StringType()))

# %%
sdf = sdf.withColumn('log_msg', udf_sq_brackets('log'))
sdf.limit(5).toPandas()
# Out:
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#                           date                        img  \
# 0  2022-12-09T04:50:48.335844Z  jupyterhub/k8s-hub:0.11.1
# 1  2022-12-09T04:50:48.359937Z  jupyterhub/k8s-hub:0.11.1
# 2  2022-12-09T04:50:55.940651Z  jupyterhub/k8s-hub:0.11.1
# 3  2022-12-09T04:50:55.968410Z  jupyterhub/k8s-hub:0.11.1
# 4  2022-12-09T04:50:51.758320Z  jupyterhub/k8s-hub:0.11.1
#
#                     hub                       host  \
# 0  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 2  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 3  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 4  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
#
#                                                  log  stream  \
# 0  [I 2022-12-09 04:50:48.335 JupyterHub log:181]...  stderr
# 1  [W 2022-12-09 04:50:48.359 JupyterHub log:181]...  stderr
# 2  [I 2022-12-09 04:50:55.940 JupyterHub log:181]...  stderr
# 3  [W 2022-12-09 04:50:55.968 JupyterHub log:181]...  stderr
# 4  [I 2022-12-09 04:50:51.758 JupyterHub log:181]...  stderr
#
#                              time  \
# 0   2022-12-09T04:50:48.33584421Z
# 1  2022-12-09T04:50:48.359937031Z
# 2  2022-12-09T04:50:55.940651688Z
# 3  2022-12-09T04:50:55.968410334Z
# 4  2022-12-09T04:50:51.758320284Z
#
#                                              log_msg
# 0  [I, 2022-12-09 04:50:48.335, JupyterHub, log, ...
# 1  [W, 2022-12-09 04:50:48.359, JupyterHub, log, ...
# 2  [I, 2022-12-09 04:50:55.940, JupyterHub, log, ...
# 3  [W, 2022-12-09 04:50:55.968, JupyterHub, log, ...
# 4  [I, 2022-12-09 04:50:51.758, JupyterHub, log, ...

# %%
sdf = sdf.select(
    'img',
    'hub',
    'host',
    F.col('log_msg')[0].alias('head'),
    F.col('log_msg')[1].alias('timestamp'),
    F.col('log_msg')[2].alias('service'),
    F.col('log_msg')[3].alias('event_type'),
    F.col('log_msg')[4].alias('event_code'),
    F.col('log_msg')[5].alias('message')
)
sdf.limit(5).toPandas()
# Out:
#                          img                   hub                       host  \
# 0  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 1  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 2  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 3  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 4  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
#
#   head                timestamp     service event_type event_code  \
# 0    I  2022-12-09 04:50:48.335  JupyterHub        log        181
# 1    W  2022-12-09 04:50:48.359  JupyterHub        log        181
# 2    I  2022-12-09 04:50:55.940  JupyterHub        log        181
# 3    W  2022-12-09 04:50:55.968  JupyterHub        log        181
# 4    I  2022-12-09 04:50:51.758  JupyterHub        log        181
#
#                                              message
# 0  302 GET /utilities/login/index.php -> /hub/uti...
# 1  404 GET /hub/utilities/login/index.php (@10.11...
# 2  302 GET /test-output/ -> /hub/test-output/ (@1...
# 3   404 GET /hub/test-output/ (@10.112.128.1) 1.19ms
# 4  302 GET /admin.pl -> /hub/admin.pl (@10.112.12...

# %% [markdown]
# #### 4.4. Find users' activities

# %%
def parce_users_activities(code, msg):
    """
    Ugly function.
    
    You may use dictionary to make it
    more pythonic or something else.
    
    """
    if code == '43':
        user = msg.split()[-1]
        log = 'logged out'
    elif code == '757':
        user = msg.split()[-1]
        log = 'logged in'
    elif code == '402':
        user = msg.split()[0]
        log = 'pending spawn'
    elif code == '1875':
        user = msg.split()[4].replace('claim-', '').replace(',', '')
        log = 'attempt to create pvc with timeout'
    elif code == '1887':
        user = msg.split()[1].replace('claim-', '')
        log = 'pvc already exists'
    elif code == '1840':
        user = msg.split()[4].replace('jupyter-', '').replace(',', '')
        log = 'attempting to create pod with timeout'
    elif code == '1344':
        user = msg.split('/')[3]
        log = 'failing suspected api request to not-running server'
    elif code == '380':
        user = msg.split()[3]
        log = 'previous spawn failed'
    elif code == '567':
        user = msg.split('/')[4]
        log = 'stream closed while handling '
    elif code == '681':
        user = msg.split()[0].replace('\'s', '')
        log = 'server failed to start'
    elif code == '1997':
        user = msg.split('-')[-1]
        log = 'deleting pod'
    elif code == '689':
        user = msg.split()[3].replace('\'s', '')
        log = 'unhandled error starting with timeout'
    elif code == '1961' or code == '2044':
        user = msg.split()[1].replace('jupyter-', '')
        log = 'restarting pod reflector'
    elif code == '257':
        user = msg.split()[2]
        log = 'adding user to proxy'
    elif code == '664':
        user = msg.split()[1]
        log = 'server is ready'
    elif code == '61' or code == '85':
        user = msg.split()[3]
        log = 'spawning sever with advanced configuration option'
    elif code == '1143':
        user = msg.split()[1].replace(':', '')
        log = 'server is slow to stop'
    elif code == '2077':
        user = msg.split()[0]
        log = 'still running'
    elif code == '167':
        user = msg.split()[1]
        log = 'server is already active'
    elif code == '1067' or code == '2022':
        user = msg.split()[1]
        log = 'user server stopped with exit code 1'
    elif code == '1857':
        user = msg.split()[3].replace('jupyter-', '').replace(',', '')
        log = 'found existing pod and attempting to kill'
    elif code == '1861':
        user = msg.split()[2].replace('jupyter-', '').replace(',', '')
        log = 'killed pod and will try starting singleuser pod again'
    elif code == '738':
        user = msg.split()[0].replace(',', '').replace('\'s', '')
        log = 'server never showed up and giving up'
    elif code == '2069':
        user = msg.split()[0].replace(',', '')
        log = 'user does not appear to be running and shutting it down'  
    elif code == '148':
        user = msg.split()[-1]
        log = 'user is running'
    elif code == '1415':
        user = msg.split()[-1]
        log = 'admin requesting spawn on behalf'
    elif code == '1437':
        user = msg.split()[5].replace(',', '')
        log = 'user requested server which user do not own'
    elif code == '626':
        user = msg.split()[1]
        log = 'server is already started'
    elif code == '2085':
        user = msg.split()[0]
        log = 'server appears to have stopped while the hub was down'
    else:
        user, log = '', ''
    return user, log

# %%
udf_parce_users_activities = udf(parce_users_activities, ArrayType(StringType()))

# %%
sdf = sdf.withColumn('user_act', udf_parce_users_activities(sdf['event_code'], sdf['message']))
sdf.limit(5).toPandas()
# Out:
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#                          img                   hub                       host  \
# 0  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 1  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 2  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 3  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
# 4  jupyterhub/k8s-hub:0.11.1  hub-5c66c6c96f-p5xcc  cl1flrrk4hvdbm084md4-ahoc
#
#   head                timestamp     service event_type event_code  \
# 0    I  2022-12-09 04:50:48.335  JupyterHub        log        181
# 1    W  2022-12-09 04:50:48.359  JupyterHub        log        181
# 2    I  2022-12-09 04:50:55.940  JupyterHub        log        181
# 3    W  2022-12-09 04:50:55.968  JupyterHub        log        181
# 4    I  2022-12-09 04:50:51.758  JupyterHub        log        181
#
#                                              message user_act
# 0  302 GET /utilities/login/index.php -> /hub/uti...     [, ]
# 1  404 GET /hub/utilities/login/index.php (@10.11...     [, ]
# 2  302 GET /test-output/ -> /hub/test-output/ (@1...     [, ]
# 3   404 GET /hub/test-output/ (@10.112.128.1) 1.19ms     [, ]
# 4  302 GET /admin.pl -> /hub/admin.pl (@10.112.12...     [, ]

# %%
sdf = sdf.select(
    'timestamp',
    'hub',
    'img',
    'host',
    'event_code',
    'event_type',
    F.col('user_act')[1].alias('log'),
    F.col('user_act')[0].alias('user')
)
sdf.limit(5).toPandas()
# Out:
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#                  timestamp                   hub                        img  \
# 0  2022-12-09 04:50:48.335  hub-5c66c6c96f-p5xcc  jupyterhub/k8s-hub:0.11.1
# 1  2022-12-09 04:50:48.359  hub-5c66c6c96f-p5xcc  jupyterhub/k8s-hub:0.11.1
# 2  2022-12-09 04:50:55.940  hub-5c66c6c96f-p5xcc  jupyterhub/k8s-hub:0.11.1
# 3  2022-12-09 04:50:55.968  hub-5c66c6c96f-p5xcc  jupyterhub/k8s-hub:0.11.1
# 4  2022-12-09 04:50:51.758  hub-5c66c6c96f-p5xcc  jupyterhub/k8s-hub:0.11.1
#
#                         host event_code event_type log user
# 0  cl1flrrk4hvdbm084md4-ahoc        181        log
# 1  cl1flrrk4hvdbm084md4-ahoc        181        log
# 2  cl1flrrk4hvdbm084md4-ahoc        181        log
# 3  cl1flrrk4hvdbm084md4-ahoc        181        log
# 4  cl1flrrk4hvdbm084md4-ahoc        181        log

# %%
sdf = sdf.filter(sdf.user != '')
sdf = sdf.withColumn(
    'timestamp',
    F.to_timestamp('timestamp', 'yyyy-MM-dd HH:mm:ss.SSS')
)
sdf.limit(5).toPandas()
# Out:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
# EOFError
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 186, in manager
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 74, in worker
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/worker.py", line 643, in main
#     if read_int(infile) == SpecialLengths.END_OF_STREAM:
#   File "/usr/local/spark/python/lib/pyspark.zip/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
#                 timestamp                   hub                        img  \
# 0 2023-02-13 09:30:12.727  hub-57c88d997b-xh654  jupyterhub/k8s-hub:0.11.1
# 1 2023-02-13 09:30:12.729  hub-57c88d997b-xh654  jupyterhub/k8s-hub:0.11.1
# 2 2023-02-13 09:30:12.730  hub-57c88d997b-xh654  jupyterhub/k8s-hub:0.11.1
# 3 2023-02-13 09:30:13.534  hub-57c88d997b-xh654  jupyterhub/k8s-hub:0.11.1
# 4 2023-02-13 09:30:13.536  hub-57c88d997b-xh654  jupyterhub/k8s-hub:0.11.1
#
#                         host event_code event_type                   log  \
# 0  cl1flrrk4hvdbm084md4-elef        257      proxy  adding user to proxy
# 1  cl1flrrk4hvdbm084md4-elef        664      users       server is ready
# 2  cl1flrrk4hvdbm084md4-elef        664      users       server is ready
# 3  cl1flrrk4hvdbm084md4-elef        257      proxy  adding user to proxy
# 4  cl1flrrk4hvdbm084md4-elef        664      users       server is ready
#
#        user
# 0  st107874
# 1  st107874
# 2  st107874
# 3  st112224
# 4  st112224

# %% [markdown]
# ### 5. Normalize data and write to database

# %% [markdown]
# #### 5.1. Users table

# %%
logins = sdf.select('user').distinct().collect()
print(len(logins))
logins = [list(x)[0] for x in logins]
logins[:5]
# Out:
# [Stage 10:================================>                    (123 + 15) / 200]
# 165
# ['st097322', 'st109438', 'st110696', 'st107590', 'st109257']

# %%
# !pip install names
# Out:
# Requirement already satisfied: names in /opt/conda/lib/python3.9/site-packages (0.3.0)

# %%
import names

# %%
users = []
for login in logins:
    user = {}
    user['login'] = login
    user['name'] = names.get_full_name()
    user['email'] = login + '@gsom.spbu.ru'
    users.append(user)

# %%
rdd = sc.parallelize([users])
sdf_users = spark.read.json(rdd)
sdf_users.printSchema()
# Out:
# root
#  |-- email: string (nullable = true)
#  |-- login: string (nullable = true)
#  |-- name: string (nullable = true)

# %%
sdf_users.show(5)
# Out:
# +--------------------+--------+---------------+
# |               email|   login|           name|
# +--------------------+--------+---------------+
# |st097322@gsom.spb...|st097322|Garrett Brannen|
# |st109438@gsom.spb...|st109438|   Tiffany Hunt|
# |st110696@gsom.spb...|st110696|    April Jones|
# |st107590@gsom.spb...|st107590|Felicia Burdett|
# |st109257@gsom.spb...|st109257|   Tina Harding|
# +--------------------+--------+---------------+
# only showing top 5 rows

# %% [markdown]
# ##### <font color='blue'>ClickHouse</font>

# %%
query = '''
DROP TABLE db1.users;
'''
rs = execute_query(query, access_ch)
rs.text
# Out:
# ''

# %%
query = '''
CREATE TABLE IF NOT EXISTS db1.users (
    email String,
    login String,
    name String
) ENGINE = MergeTree
ORDER BY email;
'''
rs = execute_query(query, access_ch)
rs
# Out:
# <Response [200]>

# %%
URL_CH = 'jdbc:clickhouse://{}:{}/{}'.format(
    access_ch['host'],
    access_ch['port'],
    access_ch['dbname']
)
DRIVER_CH = 'com.clickhouse.jdbc.ClickHouseDriver'

# %%
table_name = 'users'

sdf_users.write \
    .format('jdbc') \
    .mode('append') \
    .option('url', URL_CH) \
    .option('user', access_ch['user']) \
    .option('password', access_ch['password']) \
    .option('dbtable', table_name) \
    .option('driver', DRIVER_CH) \
    .option('ssl', 1) \
    .option('sslmode', 'strict') \
    .option('sslrootcert', f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_ch["sslrootcert"]}') \
    .save()
# Out:
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [c81b0311-4ccb-4c24-b388-795d3e6c98a3] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [282a7c10-1bfd-456f-8ff1-f068559fad24] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [f0ffeb57-9ffd-448c-9041-7f3862bfd30c] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [7bdfc280-08c2-48ec-83af-ea57092abe7b] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [6673c420-419d-47a7-9851-1293b725e3bf] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [890fddcf-9258-4948-95d2-61f3059d9dd3] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:07 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [3522f66c-0517-4caa-9edb-391dafef6f2b] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [45e5af4f-e31c-4c32-a1b1-4c6b8dfc596b] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [3f2d66e2-0655-4745-9334-0f6bb5096af1] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [4eb29939-2c7d-4860-9a65-7de576b13b94] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [4fcabd1d-cd97-4549-a544-8d79b4a5fde6] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [eb14f878-cf37-42f9-a4e1-1cf6503dfc5a] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [f00c59b9-9e62-48dd-a701-d7ce5694e1e2] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [53137403-4bf4-41fc-8878-e9ad8c14c5d7] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [a8696a9f-7f4d-4cfc-9c81-934715244360] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [f0e6bd7c-b4b9-419d-9b06-1c97aef14842] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [b3b6a31a-1dbd-4c50-8e56-f60c87bedad5] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [21528b8b-ce36-462a-b230-efbbc6cad3bf] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [b636dc31-c5ef-486a-93fc-6948befa8b81] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [7133baac-8793-4d34-81f0-20a9b9f1d3a6] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [3f4e0732-8dee-4c0e-a21a-c346e7d66f54] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [4b896dc5-1435-45e0-bb29-844d440df498] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [d9266590-f22d-4970-8a34-8892b130149e] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [807b268c-b804-45ef-8660-aa58ac402b7e] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [c9e6bcbd-ce04-464f-8ef6-2d4745d40b84] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [bb702c4d-3c5a-46c0-abea-184182b2309b] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [465af8a9-b97e-431e-afba-b91f36d94c5a] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [c7369be2-1728-41f8-b5c9-58c12077c93b] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [a94707c7-edee-4b66-892e-34c7e5a1b2d8] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [6b7c2ab2-5449-446e-a76f-e2cc3958f82c] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [b0891b5b-94d3-48b6-b192-f7ac1ae67da0] (1 queries & 0 savepoints) is committed.
# 23/04/13 11:36:08 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [cdb03b7a-2f46-4128-a4e2-f0e8b68850d9] (0 queries & 0 savepoints) is committed.

# %%
# test query
query = '''
SELECT * FROM db1.users LIMIT 5;
'''
rs = execute_query(query, access_ch)
print(rs.text)
# Out:
# aasoloviev@gsom.spbu.ru	aasoloviev	John Lawrence
# ab2216206@gsom.spbu.ru	ab2216206	Megan Davis
# ab2219090@gsom.spbu.ru	ab2219090	Mary Nelson
# abulatov@gsom.spbu.ru	abulatov	Jennifer Ramirez
# albulatov@gsom.spbu.ru	albulatov	Isabel Lucero

# %% [markdown]
# ##### <font color='green'>PostgreSQL</font>

# %%
query = '''
DROP TABLE IF EXISTS users
'''
send_query(query, access_postgres)

# %%
query = '''
CREATE TABLE IF NOT EXISTS users (
    email varchar(128),
    login varchar(32),
    name varchar(128)
);
'''
send_query(query, access_postgres)

# %%
URL_PG = 'jdbc:postgresql://{}:{}/{}'.format(
    access_postgres["host"],
    access_postgres["port"],
    access_postgres["dbname"]
)
DRIVER_PG = 'org.postgresql.Driver'

# %%
sdf_users.write\
    .mode('append') \
    .format('jdbc') \
    .option('url', URL_PG) \
    .option('dbtable', table_name) \
    .option('user', access_postgres['user']) \
    .option('password', access_postgres['password']) \
    .option('driver', DRIVER_PG) \
    .option('ssl', True) \
    .option('sslmode', 'require') \
    .save()

# %%
query = '''
SELECT * FROM users LIMIT 5;
'''
send_query(query, access_postgres, res=True)
# Out:
# [('st097322@gsom.spbu.ru', 'st097322', 'Garrett Brannen'),
#  ('st109438@gsom.spbu.ru', 'st109438', 'Tiffany Hunt'),
#  ('st110696@gsom.spbu.ru', 'st110696', 'April Jones'),
#  ('st107590@gsom.spbu.ru', 'st107590', 'Felicia Burdett'),
#  ('st109257@gsom.spbu.ru', 'st109257', 'Tina Harding')]

# %% [markdown]
# #### 5.2. JupyterHub instances table

# %%
sdf_instances = sdf.select(
    'hub',
    'img',
    'host'
)
sdf_instances = sdf_instances.dropDuplicates()

# %% [markdown]
# ##### <font color='blue'>ClickHouse</font>

# %%
query = '''
DROP TABLE db1.instances;
'''
rs = execute_query(query, access_ch)
rs.text
# Out:
# ''

# %%
query = '''
CREATE TABLE IF NOT EXISTS db1.instances (
    hub String,
    img String,
    host String
) ENGINE = MergeTree
ORDER BY hub;
'''
rs = execute_query(query, access_ch)
rs
# Out:
# <Response [200]>

# %%
table_name = 'instances'

sdf_instances.write \
    .format('jdbc') \
    .mode('append') \
    .option('url', URL_CH) \
    .option('user', access_ch['user']) \
    .option('password', access_ch['password']) \
    .option('dbtable', table_name) \
    .option('driver', DRIVER_CH) \
    .option('ssl', 1) \
    .option('sslmode', 'strict') \
    .option('sslrootcert', f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_ch["sslrootcert"]}') \
    .save()
# Out:
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [94728ffd-e186-440d-a92e-e648fba60ff9] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [d550a02f-384d-4b0c-bc68-674994d878e3] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [402af154-0e54-4205-b233-91dd685f32be] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [765b8c8f-7c0f-4df2-ade0-610690b436c2] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [38f5e2eb-8a6f-42dd-9561-34db07692c8c] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [c6bfeb1d-7c97-49b5-aa26-ed79cf9e0d1a] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [5cb4ae67-cb81-472f-b8f4-7c292aec4905] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [2017f0ec-a453-4ac4-b5dc-859fecbdd021] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [e1c274fc-68d9-4139-a740-796769b5b6d0] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [f92aeaae-7068-4273-a310-93f4b86183a3] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [75b6e1e2-80fd-49ac-85aa-fa9095d6c1d2] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [8284d920-4e95-40f4-a9ac-6ae78433070a] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [754c9fb8-c2fe-4ac2-ab60-b5cea38cbdf1] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [226638ba-9a63-4169-a731-b465f8e4c53b] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [7e361f53-5924-491e-8719-63780eba6856] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [4699e8d0-77a0-42bf-b45a-10e40095ec43] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [6fe40613-85bf-43e9-a288-181639ad48b0] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [e85f7149-ec43-4674-91bb-d8717cbca836] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [e907f935-965d-4093-8a33-562149c919fa] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [2059724c-820a-49ce-acf0-c2cb9ab48339] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [dbb6191e-d154-4c06-9480-a4a3bdb3cbac] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [b376e036-10cd-4cef-b51c-80ae3e388592] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [165687df-60ec-421d-8cd8-59552e84bcab] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [ea78007f-b571-4dc5-924a-4f4d6ccd1c2e] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [dd90edb9-bcac-4d08-a35e-11b12eaced88] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [14c126c2-f284-4671-a440-bb903e5bd60c] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:27 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [47b041e5-e83a-47e0-8449-2e71b62af6ff] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [56e16650-ef33-42d1-83c3-b01e1ab15c8d] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [dc3dff32-6663-44fb-a8bf-31006e35be1d] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [8b40222c-beea-4c25-9964-4a2eaff7c327] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [0be66faa-fba0-4bc8-8586-34a3413b4d25] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [3a59401f-40c5-49d8-ad29-b0025fa81f8d] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [f7a68610-d396-4c61-9a16-314829b5ea5f] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [a0abbfb4-dd2f-435b-b769-ef912482c690] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [8d3aa211-4f90-44ca-b361-6452beff3a1a] (2 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [e222c7c4-5810-4446-ad23-e0db7f1ee477] (0 queries & 0 savepoints) is committed.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction is not supported. You may change jdbcCompliant to false to throw SQLException instead.
# 23/04/13 11:36:28 WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction
WARN ClickHouseConnectionImpl: [JDBC Compliant Mode] Transaction [8a84d1cb-0924-47c4-98d0-d363e308156d] (0 queries & 0 savepoints) is committed.

# %%
# test query
query = '''
SELECT * FROM db1.instances LIMIT 5;
'''
rs = execute_query(query, access_ch)
print(rs.text)
# Out:
# hub-56bbc6d5f7-5wsph	jupyterhub/k8s-hub:0.11.1	cl1flrrk4hvdbm084md4-ahoc
# hub-56bbc6d5f7-rgsct	jupyterhub/k8s-hub:0.11.1	cl1flrrk4hvdbm084md4-ahoc
# hub-57c88d997b-xh654	jupyterhub/k8s-hub:0.11.1	cl1flrrk4hvdbm084md4-elef
# hub-58f6d59b46-jfwm9	jupyterhub/k8s-hub:0.11.1	cl1flrrk4hvdbm084md4-ahoc
# hub-59778cfbc5-kb9tb	jupyterhub/k8s-hub:0.11.1	cl1flrrk4hvdbm084md4-elef

# %% [markdown]
# ##### <font color='green'>PostgreSQL</font>

# %%
query = '''
DROP TABLE IF EXISTS instances
'''
send_query(query, access_postgres)

# %%
query = '''
CREATE TABLE IF NOT EXISTS instances (
    hub varchar(64),
    img varchar(64),
    host varchar(64)
);
'''
send_query(query, access_postgres)

# %%
sdf_instances.write\
    .mode('append') \
    .format('jdbc') \
    .option('url', URL_PG) \
    .option('dbtable', table_name) \
    .option('user', access_postgres['user']) \
    .option('password', access_postgres['password']) \
    .option('driver', DRIVER_PG) \
    .option('ssl', True) \
    .option('sslmode', 'require') \
    .save()

# %%
query = '''
SELECT * FROM instances LIMIT 5;
'''
send_query(query, access_postgres, res=True)
# Out:
# [('hub-69c5fcf7fb-jxwwm',
#   'jupyterhub/k8s-hub:0.11.1',
#   'cl1flrrk4hvdbm084md4-elef'),
#  ('hub-5b59fd67fc-v4shf',
#   'jupyterhub/k8s-hub:0.11.1',
#   'cl1flrrk4hvdbm084md4-okub'),
#  ('hub-7c7876787d-96fnt',
#   'jupyterhub/k8s-hub:0.11.1',
#   'cl1flrrk4hvdbm084md4-elef'),
#  ('hub-5b746df7c6-ssj98',
#   'jupyterhub/k8s-hub:0.11.1',
#   'cl1flrrk4hvdbm084md4-ahoc'),
#  ('hub-5bb9b9c56c-s958d',
#   'jupyterhub/k8s-hub:0.11.1',
#   'cl1flrrk4hvdbm084md4-ahoc')]

# %% [markdown]
# #### 5.3. JupyterHub logs table

# %%
sdf_logs = sdf.select(
    'timestamp',
    'hub',
    'event_code',
    'event_type',
    'log',
    F.col('user').alias('login')
)
sdf_logs = sdf_logs.dropDuplicates()

# %% [markdown]
# ##### <font color='blue'>ClickHouse</font>

# %%
query = '''
DROP TABLE db1.logs;
'''
rs = execute_query(query, access_ch)
rs.text
# Out:
# "Code: 60. DB::Exception: Table db1.logs doesn't exist. (UNKNOWN_TABLE) (version 23.3.1.2823 (official build))\n"

# %%
query = '''
CREATE TABLE IF NOT EXISTS db1.logs (
    timestamp DateTime,
    hub String,
    event_code Int32,
    event_type String,
    log String,
    login String
) ENGINE = MergeTree
ORDER BY hub;
'''
rs = execute_query(query, access_ch)
rs
# Out:
# <Response [200]>

# %%
table_name = 'logs'

sdf_logs.write \
    .format('jdbc') \
    .mode('append') \
    .option('url', URL_CH) \
    .option('user', access_ch['user']) \
    .option('password', access_ch['password']) \
    .option('dbtable', table_name) \
    .option('driver', DRIVER_CH) \
    .option('ssl', 1) \
    .option('sslmode', 'strict') \
    .option('sslrootcert', f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_ch["sslrootcert"]
# %% [markdown]
# ##### <font color='green'>PostgreSQL</font>

# %%
query = '''
DROP TABLE IF EXISTS logs
'''
send_query(query, access_postgres)

# %%
query = '''
CREATE TABLE IF NOT EXISTS logs (
    timestamp timestamp,
    hub varchar(64),
    event_code varchar(32),
    event_type varchar(64),
    log text,
    login varchar(32)
);
'''
send_query(query, access_postgres)

# %%
sdf_logs.write\
    .mode('append') \
    .format('jdbc') \
    .option('url', URL_PG) \
    .option('dbtable', table_name) \
    .option('user', access_postgres['user']) \
    .option('password', access_postgres['password']) \
    .option('driver', DRIVER_PG) \
    .option('ssl', True) \
    .option('sslmode', 'require') \
    .save()

# %%
query = '''
SELECT * FROM logs LIMIT 5;
'''
send_query(query, access_postgres, res=True)
# Out:
# [(datetime.datetime(2023, 2, 13, 9, 32, 22, 792000),
#   'hub-57c88d997b-xh654',
#   '402',
#   'pages',
#   'pending spawn',
#   'st112224'),
#  (datetime.datetime(2023, 2, 11, 7, 27, 31, 64000),
#   'hub-57c88d997b-xh654',
#   '402',
#   'pages',
#   'pending spawn',
#   'st108949'),
#  (datetime.datetime(2022, 9, 6, 6, 23, 39, 295000),
#   'hub-5bb9b9c56c-5k7nq',
#   '402',
#   'pages',
#   'pending spawn',
#   'st110132'),
#  (datetime.datetime(2022, 10, 25, 6, 51, 24, 576000),
#   'hub-5bb9b9c56c-5k7nq',
#   '1840',
#   'spawner',
#   'attempting to create pod with timeout',
#   'st110869'),
#  (datetime.datetime(2022, 11, 1, 8, 8, 29, 905000),
#   'hub-5bb9b9c56c-s958d',
#   '1344',
#   'base',
#   'failing suspected api request to not-running server',
#   'st051829')]

# %% [markdown]
# ### 6. How to get data back

# %% [markdown]
# #### 6.1. Requests and psycopg2 libraries

# %% [markdown]
# ##### <font color='blue'>ClickHouse</font>

# %%
query = '''
SELECT \
    ls.timestamp, \
    ls.event_code, \
    us.login, \
    us.name, \
    us.email, \
    ls.log \
FROM logs AS ls \
LEFT JOIN users AS us ON ls.login = us.login \
LIMIT 5;
'''
rs = execute_query(query, access_ch)

# %%
rs
# Out:
# <Response [200]>

# %%
rs.text
# Out:
# '2022-11-11 14:16:54\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-13 21:50:28\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-11 18:20:56\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-11 13:39:54\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-10 16:23:16\t664\tst110923\tDan Ramos\tst110923@gsom.spbu.ru\tserver is ready\n'

# %%
rs.content
# Out:
# b'2022-11-11 14:16:54\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-13 21:50:28\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-11 18:20:56\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-11 13:39:54\t1344\tst102860\tMichael Bustamante\tst102860@gsom.spbu.ru\tfailing suspected api request to not-running server\n2022-11-10 16:23:16\t664\tst110923\tDan Ramos\tst110923@gsom.spbu.ru\tserver is ready\n'

# %%
df = pd.read_csv(io.StringIO(rs.text), sep='\t', header=None)
df
# Out:
#                      0     1         2                   3  \
# 0  2022-11-11 14:16:54  1344  st102860  Michael Bustamante
# 1  2022-11-13 21:50:28  1344  st102860  Michael Bustamante
# 2  2022-11-11 18:20:56  1344  st102860  Michael Bustamante
# 3  2022-11-11 13:39:54  1344  st102860  Michael Bustamante
# 4  2022-11-10 16:23:16   664  st110923           Dan Ramos
#
#                        4                                                  5
# 0  st102860@gsom.spbu.ru  failing suspected api request to not-running s...
# 1  st102860@gsom.spbu.ru  failing suspected api request to not-running s...
# 2  st102860@gsom.spbu.ru  failing suspected api request to not-running s...
# 3  st102860@gsom.spbu.ru  failing suspected api request to not-running s...
# 4  st110923@gsom.spbu.ru                                    server is ready

# %% [markdown]
# ##### <font color='green'>PostgreSQL</font>

# %%
query = '''
SELECT \
    ls.timestamp, \
    ls.event_code, \
    us.login, \
    us.name, \
    us.email, \
    ls.log \
FROM logs AS ls \
LEFT JOIN users AS us ON ls.login = us.login \
LIMIT 5;
'''
send_query(query, access_postgres, res=True)
# Out:
# [(datetime.datetime(2023, 2, 13, 9, 32, 22, 792000),
#   '402',
#   'st112224',
#   'Serena Bender',
#   'st112224@gsom.spbu.ru',
#   'pending spawn'),
#  (datetime.datetime(2023, 2, 11, 7, 27, 31, 64000),
#   '402',
#   'st108949',
#   'Louis Carboni',
#   'st108949@gsom.spbu.ru',
#   'pending spawn'),
#  (datetime.datetime(2022, 9, 6, 6, 23, 39, 295000),
#   '402',
#   'st110132',
#   'Loretta Turner',
#   'st110132@gsom.spbu.ru',
#   'pending spawn'),
#  (datetime.datetime(2022, 10, 25, 6, 51, 24, 576000),
#   '1840',
#   'st110869',
#   'Ralph Phillips',
#   'st110869@gsom.spbu.ru',
#   'attempting to create pod with timeout'),
#  (datetime.datetime(2022, 11, 1, 8, 8, 29, 905000),
#   '1344',
#   'st051829',
#   'Carmen Stancill',
#   'st051829@gsom.spbu.ru',
#   'failing suspected api request to not-running server')]

# %% [markdown]
# #### 6.2. Spark connection

# %% [markdown]
# ##### <font color='blue'>ClickHouse</font>

# %%
table_name = 'users'

sdf_test = spark.read \
    .format('jdbc') \
    .option('url', URL_CH) \
    .option('dbtable', table_name) \
    .option('user', access_ch['user']) \
    .option('password', access_ch['password']) \
    .option('driver', DRIVER_CH) \
    .option('ssl', 1) \
    .option('sslmode', 'strict') \
    .option('sslrootcert', f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_ch["sslrootcert"]}') \
    .load()

# %%
sdf_test.show(5)
# Out:
# +--------------------+----------+----------------+
# |               email|     login|            name|
# +--------------------+----------+----------------+
# |aasoloviev@gsom.s...|aasoloviev|   John Lawrence|
# |ab2216206@gsom.sp...| ab2216206|     Megan Davis|
# |ab2219090@gsom.sp...| ab2219090|     Mary Nelson|
# |abulatov@gsom.spb...|  abulatov|Jennifer Ramirez|
# |albulatov@gsom.sp...| albulatov|   Isabel Lucero|
# +--------------------+----------+----------------+
# only showing top 5 rows

# %% [markdown]
# ##### <font color='green'>PostgreSQL</font>

# %%
sdf_test = spark.read \
    .format('jdbc') \
    .option('url', URL_PG) \
    .option('dbtable', table_name) \
    .option('user', access_postgres['user']) \
    .option('password', access_postgres['password']) \
    .option('driver', DRIVER_PG) \
    .option('ssl', True) \
    .option('sslmode', 'require') \
    .load()

# %%
sdf_test.show(5)
# Out:
# +--------------------+--------+---------------+
# |               email|   login|           name|
# +--------------------+--------+---------------+
# |st097322@gsom.spb...|st097322|Garrett Brannen|
# |st109438@gsom.spb...|st109438|   Tiffany Hunt|
# |st110696@gsom.spb...|st110696|    April Jones|
# |st107590@gsom.spb...|st107590|Felicia Burdett|
# |st109257@gsom.spb...|st109257|   Tina Harding|
# +--------------------+--------+---------------+
# only showing top 5 rows

# %% [markdown]
# #### 6.3. ClickHouse connect

# %% [markdown]
# [Python packages](https://pypi.org/project/clickhouse-connect/) for connecting Python to ClickHouse.

# %%
# !pip install clickhouse-connect
# Out:
# Collecting clickhouse-connect
#   Downloading clickhouse_connect-0.5.20-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (927 kB)
#      |████████████████████████████████| 927 kB 2.1 MB/s
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect) (2021.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect) (2021.10.8)
# Collecting lz4
#   Downloading lz4-4.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 108.6 MB/s
# Collecting zstandard
#   Downloading zstandard-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 105.7 MB/s
# Requirement already satisfied: urllib3>=1.26 in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect) (1.26.7)
# Installing collected packages: zstandard, lz4, clickhouse-connect
# Successfully installed clickhouse-connect-0.5.20 lz4-4.3.2 zstandard-0.20.0

# %%
import clickhouse_connect

# %%
client = clickhouse_connect.get_client(
    host=access_ch['host'], 
    username=access_ch['user'], 
    password=access_ch['password'],
    port=access_ch['port'],
    verify=f'/home/jovyan/__DATA/IBDT_Spring_2023/topics_labs/{access_ch["sslrootcert"]}'
)

# %%
client

# %% [markdown]
# ##### 6.3.1. Queries

# %%
client.command('SELECT COUNT(*) FROM db1.users')
# Out:
# 165

# %%
result = client.query('SELECT * FROM db1.users LIMIT 5')
result.result_rows
# Out:
# [('aasoloviev@gsom.spbu.ru', 'aasoloviev', 'John Lawrence'),
#  ('ab2216206@gsom.spbu.ru', 'ab2216206', 'Megan Davis'),
#  ('ab2219090@gsom.spbu.ru', 'ab2219090', 'Mary Nelson'),
#  ('abulatov@gsom.spbu.ru', 'abulatov', 'Jennifer Ramirez'),
#  ('albulatov@gsom.spbu.ru', 'albulatov', 'Isabel Lucero')]

# %%
parameters = {
    'table1': 'logs',
    'table2': 'users',
    'key': 'login',
    'user': 'vgarshin@gsom.spbu.ru'
}
result = client.query(
    "SELECT COUNT(*) FROM db1.{table1:Identifier} AS ls \
    LEFT JOIN db1.{table2:Identifier} AS us ON ls.{key:Identifier} = us.{key:Identifier} \
    WHERE us.email = {user: String}",
    parameters=parameters
)
result.result_rows
# Out:
# [(3593,)]

# %% [markdown]
# ##### 6.3.2. Insert data

# %%
row1 = ['test1@gsom.spbu.ru', 'test1', 'Test Number One']
row2 = ['test2@gsom.spbu.ru', 'test2', 'Test Number Two']
data = [row1, row2]
data
# Out:
# [['test1@gsom.spbu.ru', 'test1', 'Test Number One'],
#  ['test2@gsom.spbu.ru', 'test2', 'Test Number Two']]

# %%
client.insert(
    'db1.users', 
    data, 
    column_names=['email', 'login', 'name']
)

# %%
result = client.query(
    "SELECT * FROM db1.users WHERE email='test1@gsom.spbu.ru'", 
    parameters=parameters
)
result.result_rows
# Out:
# [('test1@gsom.spbu.ru', 'test1', 'Test Number One')]

# %%
parameters = {
    'table': 'users', 
    'v1': 'Test%'
}
result = client.query(
    'SELECT * FROM db1.{table:Identifier} WHERE name LIKE {v1:String}', 
    parameters=parameters
)
result.result_rows
# Out:
# [('test1@gsom.spbu.ru', 'test1', 'Test Number One'),
#  ('test2@gsom.spbu.ru', 'test2', 'Test Number Two')]
